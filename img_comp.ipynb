# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from skimage.measure import structural_similarity as ssim
def mse(imageA,imageB):
    err = np.sum((imageA.astype("float")-imageB.astype("float"))**2)
    err /= float(imageA.shape[0]*imageA.shape[1])
    return err

def compare_images(imageA, imageB, title):
    m = mse(imageA, imageB)
    s = ssim(imageA, imageB)
 
    # setup the figure
    fig = plt.figure(title)
    plt.suptitle("MSE: %.2f, SSIM: %.2f" % (m, s))
 
    # show first image
    ax = fig.add_subplot(1, 2, 1)
    plt.imshow(imageA, cmap = plt.cm.gray)
    plt.axis("off")
 
    # show the second image
    ax = fig.add_subplot(1, 2, 2)
    plt.imshow(imageB, cmap = plt.cm.gray)
    plt.axis("off")
 
    # show the images
    plt.show()
    
    return(s,m)

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop
original = cv.imread("/home/harshita/Downloads/har.jpeg",0)
contrast = cv.imread("/home/harshita/Downloads/div1.jpeg",0)
original_clone = cv.imread("/home/harshita/Downloads/har.jpeg",0)

#imageFile="/home/harshita/Downloads/WhatsApp Image 2018-10-12 at 11.48.42.jpeg"
#im1 = Image.open(imageFile)
#plt.show()
#resizing the shape of the image 
# from PIL import Image
# import os, sys
# width = height = 256

# original = im1.resize((width,height), Image.BILINEAR)
# contrast = im1.resize((width,height), Image.BILINEAR)

#shopped = cv.imread("https://images.pexels.com/photos/248797/pexels-photo-248797.jpeg?auto=compress&cs=tinysrgb&h=350")
 
#convert the images to grayscale
# imA = cv.cvtColor(original, cv.COLOR_BGR2GRAY)
# im = cv.cvtColor(contrast, cv.COLOR_BGR2GRAY)
# #shopped = cv.cvtColor(shopped, cv.COLOR_BGR2GRAY)

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("Original", original), ("Contrast", contrast)


#print('Resizing image ' + contrast + original)
 
# Resize it.
 
# loop over the images
for (i, (name, image)) in enumerate(images):
    # show the image
    ax = fig.add_subplot(1, 3, i + 1)
    ax.set_title(name)
    #plt.imshow(image, cmap = plt.cm.gray)
    plt.imshow(image.reshape(image.shape[0], image.shape[1]), cmap=plt.cm.Greys)
    plt.axis("off")

plt.show()
 
# compare the images
s,m=compare_images(original, contrast, "Imagge1 vs Image2")


if(s>0.5 and m<=1000):
        print("The person is present in the database - printing details ")
else:
        print("This person is not on the predefined dataset - employ web scraping script")



s1,m1=compare_images(original, original_clone, "Image1 vs predefined image in dataset")


    
if(s1>0.5 and m1<=1000):
        print("The person is present in the database - printing details ")
else:
        print("This person is not on the predefined dataset - employ web scraping script")
# Out:
# /home/dexter/anaconda3/lib/python3.6/site-packages/skimage/measure/_structural_similarity.py:234: skimage_deprecation: Function ``structural_similarity`` is deprecated and will be removed in version 0.14. Use ``compare_ssim`` instead.
#   def structural_similarity(X, Y, win_size=None, gradient=False,
# This person is not on the predefined dataset - employ web scraping script
